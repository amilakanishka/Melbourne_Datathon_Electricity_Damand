# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
dataset = pd.read_csv('demand.csv')

# %%
noCovidDS = dataset.loc[dataset.covid ==0]

# %%
ax2 = dataset.plot.scatter(figsize=(10, 6), x='Date', y='Demand_GWh',ylim=(150,350))
plt.xlabel("Date", labelpad=10)
plt.ylabel("Daily Electricity Consumption GWh", labelpad=15)
plt.title("Victoria Electricity Daily Electricity Consumption", fontsize=16);
plt.show()

# %%
figure, axes = plt.subplots(1, 2)
dataset.plot.scatter(ax=axes[0], x='MinTemp', y='Demand_GWh',ylim=(150,350))
dataset.plot.scatter(ax=axes[1], x='MaxTemp', y='Demand_GWh',ylim=(150,350))
figure.set_figheight(6)
figure.set_figwidth(12)
figure.suptitle("Victoria Electricity Consumption vs Temperature", fontsize=16);
plt.tight_layout()

# %%
figure, axes = plt.subplots(1, 3)
dataset.plot.scatter(ax=axes[0], x='covid', y='Demand_GWh',ylim=(150,350))
dataset.plot.scatter(ax=axes[1], x='public_holiday', y='Demand_GWh',ylim=(150,350))
dataset.plot.scatter(ax=axes[2], x='wk_end', y='Demand_GWh',ylim=(150,350))
# plt.xticks(np.arange(0, 2))
plt.setp(axes, xticks=[0,1], xticklabels=['0', '1'])
figure.set_figheight(6)
figure.set_figwidth(10)
figure.suptitle("Victoria Electricity Consumption vs Other Parameters", fontsize=16);
plt.tight_layout()

# %% [markdown]
# Statistical Significance

# %%
st.ttest_ind(dataset.loc[dataset.covid == 0]['Demand_GWh'].sample(n = 50), dataset.loc[dataset.covid == 1]['Demand_GWh'].sample(n = 50), equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.04091974982699583, pvalue=0.9674443811322968)

# %%
st.ttest_ind(dataset.loc[dataset.public_holiday == 0]['Demand_GWh'].sample(n = 20), dataset.loc[dataset.public_holiday == 1]['Demand_GWh'].sample(n = 20), equal_var=False)
# Out:
# Ttest_indResult(statistic=4.129475584075377, pvalue=0.0002396296857378249)

# %%
st.ttest_ind(dataset.loc[dataset.wk_end == 0]['Demand_GWh'].sample(n = 50), dataset.loc[dataset.wk_end == 1]['Demand_GWh'].sample(n = 50), equal_var=False)
# Out:
# Ttest_indResult(statistic=8.340993195109581, pvalue=5.114230516878099e-13)

# %%
st.ttest_ind(dataset.loc[((dataset.MinTemp >= 5) & (dataset.MinTemp < 10)) ]['Demand_GWh'].sample(n = 50), dataset.loc[((dataset.MinTemp >= 10) & (dataset.MinTemp < 15))]['Demand_GWh'].sample(n = 50), equal_var=False)
# Out:
# Ttest_indResult(statistic=4.4412271899593385, pvalue=2.3657642835939733e-05)

# %%
st.ttest_ind(dataset.loc[((dataset.MaxTemp >= 10) & (dataset.MaxTemp < 15)) ]['Demand_GWh'].sample(n = 50), dataset.loc[((dataset.MaxTemp >= 15) & (dataset.MaxTemp < 20))]['Demand_GWh'].sample(n = 50), equal_var=False)
# Out:
# Ttest_indResult(statistic=5.242040561383898, pvalue=1.0085815567953732e-06)

# %%
st.ttest_ind(dataset.loc[dataset.Population == 6244863]['Demand_GWh'].sample(n = 20), dataset.loc[dataset.Population == 6689377]['Demand_GWh'].sample(n = 20), equal_var=False)
# Out:
# Ttest_indResult(statistic=0.5906827551040508, pvalue=0.5582438534338368)

# %% [markdown]
# # Electricity Demand Modelling

# %%
X = dataset[["MinTemp","MaxTemp","wk_end","public_holiday","Population","covid","year","month","day"]]
X2 = dataset[["MinTemp","MaxTemp","wk_end","public_holiday","Population","year","month","day"]]
y = dataset["Demand_GWh"].values.reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y, random_state=42)
print(X.shape, y.shape)
# Out:
# (1369, 9) (1369, 1)

# %%
X3 = noCovidDS[["MinTemp","MaxTemp","wk_end","public_holiday","Population","year","month","day"]]
y3 = noCovidDS["Demand_GWh"].values.reshape(-1, 1)
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, random_state=42)

# %%
X_train.head()
# Out:
#       MinTemp  MaxTemp  wk_end  public_holiday  Population  covid  year  \
# 1117     12.9     22.6       0               0     6655284      0  2020
# 785      18.0     34.2       0               0     6528601      0  2019
# 96       12.7     26.2       0               0     6292584      0  2017
# 415      14.1     29.5       0               0     6387081      0  2018
# 350      15.7     24.5       1               0     6387081      0  2017
#
#       month  day
# 1117      1   23
# 785       2   25
# 96        4    7
# 415       2   20
# 350      12   17

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data
X_train_scaled = StandardScaler().fit_transform(X_train.values)
X_test_scaled = StandardScaler().fit_transform(X_test.values)
X2_train_scaled = StandardScaler().fit_transform(X2_train.values)
X2_test_scaled = StandardScaler().fit_transform(X2_test.values)
X3_train_scaled = StandardScaler().fit_transform(X3_train.values)
X3_test_scaled = StandardScaler().fit_transform(X3_test.values)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train_scaled, y_train)
training_score = model.score(X_train_scaled, y_train)
testing_score = model.score(X_test_scaled, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.33589340101606846
# Testing Score: 0.3849388307520464

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Use our model to predict a value
predicted = model.predict(X_train_scaled)

# Score the prediction with mse and r2
mse = mean_squared_error(y_train, predicted)
r2 = r2_score(y_train, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 496.28987875761584
# R-squared (R2 ): 0.33589340101606846

# %% [markdown]
# # SGD

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
# SkLearn SGD classifier
clf_ = SGDRegressor()
clf_.fit(X_train_scaled, y_train)
plt.scatter(y_test,clf_.predict(X_test_scaled))
plt.grid()
plt.xlabel('Actual y')
plt.ylabel('Predicted y')
plt.title('scatter plot between actual y and predicted y')
plt.show()
print('Mean Squared Error :',mean_squared_error(y_test, clf_.predict(X_test_scaled)))
print('Mean Absolute Error :',mean_absolute_error(y_test, clf_.predict(X_test_scaled)))
# Out:
# C:\ProgramData\Anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Mean Squared Error : 448.07120462189636
# Mean Absolute Error : 17.408793348210516

# %% [markdown]
# # Deep Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor

# %% [markdown]
# Nh = Ns/(α∗ (Ni + No))
#
# Nh = Number of hidden layers.
# Ni = number of input neurons.
# No = number of output neurons.
# Ns = number of samples in training data set.
# α = an arbitrary scaling factor usually 2-10.

# %%
def create_model(optimizer='adam',input_dim=9):
    # Create model and add layers
    model = Sequential()

    # Adding the input layer and the first hidden layer
    # model.add(Dense(128, activation = 'relu', input_dim = 11))
    model.add(Dense(64, activation = 'relu', input_dim = input_dim))
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 64, activation = 'relu'))

    # Adding the output layer
    # model.add(Dense(units = 1))
    model.add(Dense(1, activation="relu"))
    # Compile and fit the model
    model.compile(loss="mean_squared_error", optimizer=optimizer)
    return model

# %% [markdown]
# model = KerasRegressor(build_fn=create_model, verbose=0)
#
# batch_size = [5, 6, 7, 8, 9, 10, 15, 20]
# epochs = [10, 25, 50, 100, 200]
# param_grid = dict(batch_size=batch_size, epochs=epochs,optimizer=optimizer)
# grid = GridSearchCV(estimator=model, param_grid=param_grid)
#
# grid_result = grid.fit(X_train_scaled, y_train)

# %% [markdown]
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, stdev, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, stdev, param))

# %% [markdown]
# predictions = grid.predict(X_test_scaled)

# %% [markdown]
# from sklearn.metrics import r2_score
# r2_score(y_test, predictions)

# %%
model1 = create_model()
history = model1.fit(
    X_train_scaled,
    y_train,
    epochs=200,
    batch_size = 6,
#     shuffle=True,
    verbose=1
)
# Out:
# Train on 1026 samples
# Epoch 1/200
# 1026/1026 [==============================] - 1s 1ms/sample - loss: 10035.8921
# Epoch 2/200
# 1026/1026 [==============================] - 0s 300us/sample - loss: 565.8946
# Epoch 3/200
# 1026/1026 [==============================] - 0s 292us/sample - loss: 311.7672
# Epoch 4/200
# 1026/1026 [==============================] - 0s 306us/sample - loss: 235.7977
# Epoch 5/200
# 1026/1026 [==============================] - 0s 303us/sample - loss: 204.9226
# Epoch 6/200
# 1026/1026 [==============================] - 0s 292us/sample - loss: 175.2373
# Epoch 7/200
# 1026/1026 [==============================] - 0s 306us/sample - loss: 198.6824
# Epoch 8/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 174.1150
# Epoch 9/200
# 1026/1026 [==============================] - 0s 283us/sample - loss: 158.6672
# Epoch 10/200
# 1026/1026 [==============================] - 0s 294us/sample - loss: 170.5885
# Epoch 11/200
# 1026/1026 [==============================] - 0s 288us/sample - loss: 161.2522
# Epoch 12/200
# 1026/1026 [==============================] - 0s 291us/sample - loss: 141.9891
# Epoch 13/200
# 1026/1026 [==============================] - 0s 297us/sample - loss: 141.2756
# Epoch 14/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 187.5069
# Epoch 15/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 138.3212
# Epoch 16/200
# 1026/1026 [==============================] - 0s 297us/sample - loss: 138.4565
# Epoch 17/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 149.0636
# Epoch 18/200
# 1026/1026 [==============================] - 0s 297us/sample - loss: 155.5837
# Epoch 19/200
# 1026/1026 [==============================] - 0s 289us/sample - loss: 135.9841
# Epoch 20/200
# 1026/1026 [==============================] - 0s 289us/sample - loss: 134.2520
# Epoch 21/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 135.5954
# Epoch 22/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 157.9150
# Epoch 23/200
# 1026/1026 [==============================] - 0s 301us/sample - loss: 142.4640
# Epoch 24/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 135.9640
# Epoch 25/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 125.4688
# Epoch 26/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 121.0719
# Epoch 27/200
# 1026/1026 [==============================] - 0s 311us/sample - loss: 133.0237
# Epoch 28/200
# 1026/1026 [==============================] - 0s 292us/sample - loss: 121.0994
# Epoch 29/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 140.2211
# Epoch 30/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 136.0711
# Epoch 31/200
# 1026/1026 [==============================] - 0s 291us/sample - loss: 107.1982
# Epoch 32/200
# 1026/1026 [==============================] - 0s 300us/sample - loss: 126.3672
# Epoch 33/200
# 1026/1026 [==============================] - 0s 297us/sample - loss: 128.4030
# Epoch 34/200
# 1026/1026 [==============================] - 0s 300us/sample - loss: 106.0325
# Epoch 35/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 127.4980
# Epoch 36/200
# 1026/1026 [==============================] - 0s 287us/sample - loss: 110.7277
# Epoch 37/200
# 1026/1026 [==============================] - 0s 307us/sample - loss: 104.0427
# Epoch 38/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 128.2079
# Epoch 39/200
# 1026/1026 [==============================] - 0s 306us/sample - loss: 139.5792
# Epoch 40/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 108.2147
# Epoch 41/200
# 1026/1026 [==============================] - 0s 291us/sample - loss: 100.5151
# Epoch 42/200
# 1026/1026 [==============================] - 0s 303us/sample - loss: 111.9123
# Epoch 43/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 120.1491
# Epoch 44/200
# 1026/1026 [==============================] - 0s 331us/sample - loss: 100.3014
# Epoch 45/200
# 1026/1026 [==============================] - 0s 299us/sample - loss: 87.4919
# Epoch 46/200
# 1026/1026 [==============================] - 0s 294us/sample - loss: 94.2990
# Epoch 47/200
# 1026/1026 [==============================] - 0s 299us/sample - loss: 111.4870
# Epoch 48/200
# 1026/1026 [==============================] - 0s 289us/sample - loss: 110.9165
# Epoch 49/200
# 1026/1026 [==============================] - 0s 289us/sample - loss: 114.6733
# Epoch 50/200
# 1026/1026 [==============================] - 0s 298us/sample - loss: 131.8447
# Epoch 51/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 93.5945
# Epoch 52/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 99.7667
# Epoch 53/200
# 1026/1026 [==============================] - 0s 301us/sample - loss: 114.1536
# Epoch 54/200
# 1026/1026 [==============================] - 0s 296us/sample - loss: 86.8060
# Epoch 55/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 96.8792
# Epoch 56/200
# 1026/1026 [==============================] - 0s 272us/sample - loss: 92.0002
# Epoch 57/200
# 1026/1026 [==============================] - 0s 266us/sample - loss: 92.4014
# Epoch 58/200
# 1026/1026 [==============================] - 0s 268us/sample - loss: 86.9752
# Epoch 59/200
# 1026/1026 [==============================] - 0s 278us/sample - loss: 84.2316
# Epoch 60/200
# 1026/1026 [==============================] - 0s 286us/sample - loss: 104.4912
# Epoch 61/200
# 1026/1026 [==============================] - 0s 267us/sample - loss: 90.9420
# Epoch 62/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 101.8848
# Epoch 63/200
# 1026/1026 [==============================] - 0s 272us/sample - loss: 82.0751
# Epoch 64/200
# 1026/1026 [==============================] - 0s 283us/sample - loss: 77.1989
# Epoch 65/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 96.2878
# Epoch 66/200
# 1026/1026 [==============================] - 0s 272us/sample - loss: 72.7711
# Epoch 67/200
# 1026/1026 [==============================] - 0s 277us/sample - loss: 111.9564
# Epoch 68/200
# 1026/1026 [==============================] - 0s 281us/sample - loss: 84.3849
# Epoch 69/200
# 1026/1026 [==============================] - 0s 270us/sample - loss: 65.5380
# Epoch 70/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 83.0138
# Epoch 71/200
# 1026/1026 [==============================] - 0s 284us/sample - loss: 67.6152
# Epoch 72/200
# 1026/1026 [==============================] - 0s 276us/sample - loss: 78.5423
# Epoch 73/200
# 1026/1026 [==============================] - 0s 268us/sample - loss: 137.4372
# Epoch 74/200
# 1026/1026 [==============================] - 0s 279us/sample - loss: 86.5403 - los
# Epoch 75/200
# 1026/1026 [==============================] - 0s 278us/sample - loss: 77.0530
# Epoch 76/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 84.0498
# Epoch 77/200
# 1026/1026 [==============================] - 0s 277us/sample - loss: 112.7948
# Epoch 78/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 75.9523
# Epoch 79/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 81.1999
# Epoch 80/200
# 1026/1026 [==============================] - 0s 289us/sample - loss: 95.8459
# Epoch 81/200
# 1026/1026 [==============================] - 0s 286us/sample - loss: 81.4550
# Epoch 82/200
# 1026/1026 [==============================] - 0s 267us/sample - loss: 69.2726
# Epoch 83/200
# 1026/1026 [==============================] - 0s 276us/sample - loss: 71.7351
# Epoch 84/200
# 1026/1026 [==============================] - 0s 268us/sample - loss: 80.3974
# Epoch 85/200
# 1026/1026 [==============================] - 0s 276us/sample - loss: 77.4945
# Epoch 86/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 99.6553
# Epoch 87/200
# 1026/1026 [==============================] - 0s 279us/sample - loss: 68.1064
# Epoch 88/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 77.7838
# Epoch 89/200
# 1026/1026 [==============================] - 0s 271us/sample - loss: 66.8877
# Epoch 90/200
# 1026/1026 [==============================] - 0s 264us/sample - loss: 77.6342
# Epoch 91/200
# 1026/1026 [==============================] - 0s 270us/sample - loss: 78.8960
# Epoch 92/200
# 1026/1026 [==============================] - 0s 280us/sample - loss: 84.3445
# Epoch 93/200
# 1026/1026 [==============================] - 0s 268us/sample - loss: 61.6085
# Epoch 94/200
# 1026/1026 [==============================] - 0s 272us/sample - loss: 65.1779
# Epoch 95/200
# 1026/1026 [==============================] - 0s 276us/sample - loss: 72.7612
# Epoch 96/200
# 1026/1026 [==============================] - 0s 271us/sample - loss: 78.6060
# Epoch 97/200
# 1026/1026 [==============================] - 0s 267us/sample - loss: 75.3416
# Epoch 98/200
# 1026/1026 [==============================] - 0s 266us/sample - loss: 69.2336
# Epoch 99/200
# 1026/1026 [==============================] - 0s 275us/sample - loss: 55.2659
# Epoch 100/200
# 1026/1026 [==============================] - 0s 272us/sample - loss: 55.4609
# Epoch 101/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 64.4982
# Epoch 102/200
# 1026/1026 [==============================] - 0s 282us/sample - loss: 76.9464
# Epoch 103/200
# 1026/1026 [==============================] - 0s 281us/sample - loss: 59.8002
# Epoch 104/200
# 1026/1026 [==============================] - 0s 268us/sample - loss: 65.1646
# Epoch 105/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 61.0676
# Epoch 106/200
# 1026/1026 [==============================] - 0s 278us/sample - loss: 63.0536
# Epoch 107/200
# 1026/1026 [==============================] - 0s 283us/sample - loss: 58.7476
# Epoch 108/200
# 1026/1026 [==============================] - 0s 275us/sample - loss: 69.3444
# Epoch 109/200
# 1026/1026 [==============================] - 0s 284us/sample - loss: 73.2534
# Epoch 110/200
# 1026/1026 [==============================] - 0s 275us/sample - loss: 68.5868
# Epoch 111/200
# 1026/1026 [==============================] - 0s 279us/sample - loss: 74.4521
# Epoch 112/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 77.9373
# Epoch 113/200
# 1026/1026 [==============================] - 0s 283us/sample - loss: 51.2675
# Epoch 114/200
# 1026/1026 [==============================] - 0s 271us/sample - loss: 60.7953
# Epoch 115/200
# 1026/1026 [==============================] - 0s 270us/sample - loss: 50.8698
# Epoch 116/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 62.0194
# Epoch 117/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 72.0918
# Epoch 118/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 68.8505
# Epoch 119/200
# 1026/1026 [==============================] - 0s 270us/sample - loss: 66.8430
# Epoch 120/200
# 1026/1026 [==============================] - 0s 281us/sample - loss: 62.9045
# Epoch 121/200
# 1026/1026 [==============================] - 0s 291us/sample - loss: 56.8301
# Epoch 122/200
# 1026/1026 [==============================] - 0s 276us/sample - loss: 51.0668
# Epoch 123/200
# 1026/1026 [==============================] - 0s 286us/sample - loss: 50.0167
# Epoch 124/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 53.8771
# Epoch 125/200
# 1026/1026 [==============================] - 0s 276us/sample - loss: 62.7945
# Epoch 126/200
# 1026/1026 [==============================] - 0s 276us/sample - loss: 63.2691
# Epoch 127/200
# 1026/1026 [==============================] - 0s 280us/sample - loss: 63.9581
# Epoch 128/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 50.3557
# Epoch 129/200
# 1026/1026 [==============================] - 0s 275us/sample - loss: 52.8578
# Epoch 130/200
# 1026/1026 [==============================] - 0s 279us/sample - loss: 44.5326
# Epoch 131/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 58.7539
# Epoch 132/200
# 1026/1026 [==============================] - 0s 267us/sample - loss: 50.4378
# Epoch 133/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 48.2088
# Epoch 134/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 42.5713
# Epoch 135/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 54.8657
# Epoch 136/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 49.2926
# Epoch 137/200
# 1026/1026 [==============================] - 0s 271us/sample - loss: 49.8740
# Epoch 138/200
# 1026/1026 [==============================] - 0s 272us/sample - loss: 51.1624
# Epoch 139/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 51.5687
# Epoch 140/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 49.7607
# Epoch 141/200
# 1026/1026 [==============================] - 0s 284us/sample - loss: 55.5212
# Epoch 142/200
# 1026/1026 [==============================] - 0s 282us/sample - loss: 44.5482
# Epoch 143/200
# 1026/1026 [==============================] - 0s 275us/sample - loss: 52.3105
# Epoch 144/200
# 1026/1026 [==============================] - 0s 280us/sample - loss: 45.6622
# Epoch 145/200
# 1026/1026 [==============================] - 0s 278us/sample - loss: 42.8671
# Epoch 146/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 37.2118
# Epoch 147/200
# 1026/1026 [==============================] - 0s 271us/sample - loss: 78.0858
# Epoch 148/200
# 1026/1026 [==============================] - 0s 275us/sample - loss: 45.6029
# Epoch 149/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 41.4250
# Epoch 150/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 45.2727
# Epoch 151/200
# 1026/1026 [==============================] - 0s 277us/sample - loss: 42.7293
# Epoch 152/200
# 1026/1026 [==============================] - 0s 299us/sample - loss: 41.0992
# Epoch 153/200
# 1026/1026 [==============================] - 0s 272us/sample - loss: 50.5566
# Epoch 154/200
# 1026/1026 [==============================] - 0s 266us/sample - loss: 73.5513
# Epoch 155/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 46.1343
# Epoch 156/200
# 1026/1026 [==============================] - 0s 275us/sample - loss: 40.3707
# Epoch 157/200
# 1026/1026 [==============================] - 0s 277us/sample - loss: 40.5845
# Epoch 158/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 42.8882
# Epoch 159/200
# 1026/1026 [==============================] - 0s 287us/sample - loss: 43.6721
# Epoch 160/200
# 1026/1026 [==============================] - 0s 266us/sample - loss: 45.9852
# Epoch 161/200
# 1026/1026 [==============================] - 0s 272us/sample - loss: 43.3427
# Epoch 162/200
# 1026/1026 [==============================] - 0s 282us/sample - loss: 38.9525
# Epoch 163/200
# 1026/1026 [==============================] - 0s 271us/sample - loss: 48.7989
# Epoch 164/200
# 1026/1026 [==============================] - 0s 271us/sample - loss: 37.9626
# Epoch 165/200
# 1026/1026 [==============================] - 0s 267us/sample - loss: 31.2971
# Epoch 166/200
# 1026/1026 [==============================] - 0s 275us/sample - loss: 53.2966
# Epoch 167/200
# 1026/1026 [==============================] - 0s 270us/sample - loss: 42.1773
# Epoch 168/200
# 1026/1026 [==============================] - 0s 312us/sample - loss: 35.3121
# Epoch 169/200
# 1026/1026 [==============================] - 0s 322us/sample - loss: 38.1267
# Epoch 170/200
# 1026/1026 [==============================] - 0s 311us/sample - loss: 42.6356
# Epoch 171/200
# 1026/1026 [==============================] - 0s 302us/sample - loss: 37.6330
# Epoch 172/200
# 1026/1026 [==============================] - 0s 304us/sample - loss: 47.6861
# Epoch 173/200
# 1026/1026 [==============================] - 0s 300us/sample - loss: 42.4507
# Epoch 174/200
# 1026/1026 [==============================] - 0s 296us/sample - loss: 44.6296
# Epoch 175/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 47.3760
# Epoch 176/200
# 1026/1026 [==============================] - 0s 272us/sample - loss: 47.1036
# Epoch 177/200
# 1026/1026 [==============================] - 0s 278us/sample - loss: 46.4252
# Epoch 178/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 29.8344
# Epoch 179/200
# 1026/1026 [==============================] - 0s 280us/sample - loss: 44.4779
# Epoch 180/200
# 1026/1026 [==============================] - 0s 279us/sample - loss: 56.6821
# Epoch 181/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 41.5103
# Epoch 182/200
# 1026/1026 [==============================] - 0s 277us/sample - loss: 33.8867
# Epoch 183/200
# 1026/1026 [==============================] - 0s 280us/sample - loss: 31.8912
# Epoch 184/200
# 1026/1026 [==============================] - 0s 275us/sample - loss: 45.7695
# Epoch 185/200
# 1026/1026 [==============================] - 0s 279us/sample - loss: 27.5919
# Epoch 186/200
# 1026/1026 [==============================] - 0s 281us/sample - loss: 33.3015
# Epoch 187/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 36.3275
# Epoch 188/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 31.9521
# Epoch 189/200
# 1026/1026 [==============================] - 0s 281us/sample - loss: 27.2924
# Epoch 190/200
# 1026/1026 [==============================] - 0s 280us/sample - loss: 32.7462
# Epoch 191/200
# 1026/1026 [==============================] - 0s 279us/sample - loss: 34.3517
# Epoch 192/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 33.2065
# Epoch 193/200
# 1026/1026 [==============================] - 0s 282us/sample - loss: 30.5289
# Epoch 194/200
# 1026/1026 [==============================] - 0s 279us/sample - loss: 53.5924
# Epoch 195/200
# 1026/1026 [==============================] - 0s 275us/sample - loss: 38.1870
# Epoch 196/200
# 1026/1026 [==============================] - 0s 288us/sample - loss: 31.2648
# Epoch 197/200
# 1026/1026 [==============================] - 0s 280us/sample - loss: 33.8798
# Epoch 198/200
# 1026/1026 [==============================] - 0s 279us/sample - loss: 28.7486
# Epoch 199/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 27.4862
# Epoch 200/200
# 1026/1026 [==============================] - 0s 283us/sample - loss: 31.3437

# %%
model2 = create_model(input_dim=8)
history = model2.fit(
    X2_train_scaled,
    y2_train,
    epochs=200,
    batch_size = 6,
#     shuffle=True,
    verbose=1
)
# Out:
# Train on 1026 samples
# Epoch 1/200
# 1026/1026 [==============================] - 1s 937us/sample - loss: 12369.8834
# Epoch 2/200
# 1026/1026 [==============================] - 0s 297us/sample - loss: 664.7373
# Epoch 3/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 356.2841
# Epoch 4/200
# 1026/1026 [==============================] - 0s 288us/sample - loss: 243.5575
# Epoch 5/200
# 1026/1026 [==============================] - 0s 288us/sample - loss: 192.2710
# Epoch 6/200
# 1026/1026 [==============================] - 0s 283us/sample - loss: 166.8043
# Epoch 7/200
# 1026/1026 [==============================] - 0s 288us/sample - loss: 176.9702
# Epoch 8/200
# 1026/1026 [==============================] - 0s 292us/sample - loss: 178.2515
# Epoch 9/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 170.0327
# Epoch 10/200
# 1026/1026 [==============================] - 0s 287us/sample - loss: 165.9796
# Epoch 11/200
# 1026/1026 [==============================] - 0s 292us/sample - loss: 155.3589
# Epoch 12/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 200.5751
# Epoch 13/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 136.2148
# Epoch 14/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 147.6694
# Epoch 15/200
# 1026/1026 [==============================] - 0s 296us/sample - loss: 144.4638
# Epoch 16/200
# 1026/1026 [==============================] - 0s 284us/sample - loss: 134.6190
# Epoch 17/200
# 1026/1026 [==============================] - 0s 310us/sample - loss: 169.7096
# Epoch 18/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 141.7507
# Epoch 19/200
# 1026/1026 [==============================] - 0s 292us/sample - loss: 181.7199
# Epoch 20/200
# 1026/1026 [==============================] - 0s 296us/sample - loss: 163.7636
# Epoch 21/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 129.1326
# Epoch 22/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 122.8704
# Epoch 23/200
# 1026/1026 [==============================] - 0s 288us/sample - loss: 164.9897
# Epoch 24/200
# 1026/1026 [==============================] - 0s 299us/sample - loss: 137.4829
# Epoch 25/200
# 1026/1026 [==============================] - 0s 289us/sample - loss: 120.9458
# Epoch 26/200
# 1026/1026 [==============================] - 0s 302us/sample - loss: 111.5045
# Epoch 27/200
# 1026/1026 [==============================] - 0s 297us/sample - loss: 95.0698
# Epoch 28/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 128.6919
# Epoch 29/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 117.5145
# Epoch 30/200
# 1026/1026 [==============================] - 0s 299us/sample - loss: 120.6417
# Epoch 31/200
# 1026/1026 [==============================] - 0s 286us/sample - loss: 123.9357
# Epoch 32/200
# 1026/1026 [==============================] - 0s 292us/sample - loss: 103.8336
# Epoch 33/200
# 1026/1026 [==============================] - 0s 296us/sample - loss: 113.2610
# Epoch 34/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 100.3580
# Epoch 35/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 91.4420
# Epoch 36/200
# 1026/1026 [==============================] - 0s 329us/sample - loss: 102.1672
# Epoch 37/200
# 1026/1026 [==============================] - 0s 298us/sample - loss: 111.3156
# Epoch 38/200
# 1026/1026 [==============================] - 0s 291us/sample - loss: 97.0113
# Epoch 39/200
# 1026/1026 [==============================] - 0s 299us/sample - loss: 104.3119
# Epoch 40/200
# 1026/1026 [==============================] - 0s 286us/sample - loss: 138.6415
# Epoch 41/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 130.5959
# Epoch 42/200
# 1026/1026 [==============================] - 0s 291us/sample - loss: 97.2951
# Epoch 43/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 112.2578
# Epoch 44/200
# 1026/1026 [==============================] - 0s 284us/sample - loss: 133.6480
# Epoch 45/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 100.6469
# Epoch 46/200
# 1026/1026 [==============================] - 0s 286us/sample - loss: 99.8607
# Epoch 47/200
# 1026/1026 [==============================] - 0s 288us/sample - loss: 87.7677
# Epoch 48/200
# 1026/1026 [==============================] - 0s 287us/sample - loss: 123.2291
# Epoch 49/200
# 1026/1026 [==============================] - 0s 288us/sample - loss: 94.0490
# Epoch 50/200
# 1026/1026 [==============================] - 0s 286us/sample - loss: 86.2287
# Epoch 51/200
# 1026/1026 [==============================] - 0s 286us/sample - loss: 108.7460
# Epoch 52/200
# 1026/1026 [==============================] - 0s 298us/sample - loss: 73.6665
# Epoch 53/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 89.4219
# Epoch 54/200
# 1026/1026 [==============================] - 0s 321us/sample - loss: 89.2288
# Epoch 55/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 84.2862
# Epoch 56/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 76.3181
# Epoch 57/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 82.2254
# Epoch 58/200
# 1026/1026 [==============================] - 0s 263us/sample - loss: 93.0104
# Epoch 59/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 75.6818
# Epoch 60/200
# 1026/1026 [==============================] - 0s 270us/sample - loss: 92.5900
# Epoch 61/200
# 1026/1026 [==============================] - 0s 282us/sample - loss: 74.6485
# Epoch 62/200
# 1026/1026 [==============================] - 0s 270us/sample - loss: 83.0699
# Epoch 63/200
# 1026/1026 [==============================] - 0s 277us/sample - loss: 72.4139
# Epoch 64/200
# 1026/1026 [==============================] - 0s 284us/sample - loss: 113.2324
# Epoch 65/200
# 1026/1026 [==============================] - 0s 284us/sample - loss: 86.2316
# Epoch 66/200
# 1026/1026 [==============================] - 0s 286us/sample - loss: 83.8522
# Epoch 67/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 77.6030
# Epoch 68/200
# 1026/1026 [==============================] - 0s 294us/sample - loss: 95.7537
# Epoch 69/200
# 1026/1026 [==============================] - 0s 287us/sample - loss: 97.9878
# Epoch 70/200
# 1026/1026 [==============================] - 0s 294us/sample - loss: 76.4126
# Epoch 71/200
# 1026/1026 [==============================] - 0s 294us/sample - loss: 81.3351
# Epoch 72/200
# 1026/1026 [==============================] - 0s 300us/sample - loss: 70.9426
# Epoch 73/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 80.8430
# Epoch 74/200
# 1026/1026 [==============================] - 0s 301us/sample - loss: 73.6105
# Epoch 75/200
# 1026/1026 [==============================] - 0s 306us/sample - loss: 87.5970
# Epoch 76/200
# 1026/1026 [==============================] - 0s 323us/sample - loss: 79.5863
# Epoch 77/200
# 1026/1026 [==============================] - 0s 330us/sample - loss: 81.5424
# Epoch 78/200
# 1026/1026 [==============================] - 0s 355us/sample - loss: 77.3525
# Epoch 79/200
# 1026/1026 [==============================] - 0s 328us/sample - loss: 82.8911
# Epoch 80/200
# 1026/1026 [==============================] - 0s 340us/sample - loss: 64.7571
# Epoch 81/200
# 1026/1026 [==============================] - 0s 368us/sample - loss: 87.4753
# Epoch 82/200
# 1026/1026 [==============================] - 0s 326us/sample - loss: 63.9081
# Epoch 83/200
# 1026/1026 [==============================] - 0s 337us/sample - loss: 91.8502
# Epoch 84/200
# 1026/1026 [==============================] - 0s 368us/sample - loss: 86.1284
# Epoch 85/200
# 1026/1026 [==============================] - 0s 335us/sample - loss: 59.8199
# Epoch 86/200
# 1026/1026 [==============================] - 0s 344us/sample - loss: 72.3056
# Epoch 87/200
# 1026/1026 [==============================] - 0s 322us/sample - loss: 71.4219
# Epoch 88/200
# 1026/1026 [==============================] - 0s 338us/sample - loss: 76.1162
# Epoch 89/200
# 1026/1026 [==============================] - 0s 342us/sample - loss: 65.3738
# Epoch 90/200
# 1026/1026 [==============================] - 0s 351us/sample - loss: 68.9521
# Epoch 91/200
# 1026/1026 [==============================] - 0s 301us/sample - loss: 58.3385
# Epoch 92/200
# 1026/1026 [==============================] - 0s 331us/sample - loss: 63.3750
# Epoch 93/200
# 1026/1026 [==============================] - 0s 301us/sample - loss: 67.9706
# Epoch 94/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 82.1463
# Epoch 95/200
# 1026/1026 [==============================] - 0s 289us/sample - loss: 69.4384
# Epoch 96/200
# 1026/1026 [==============================] - 0s 288us/sample - loss: 59.5617
# Epoch 97/200
# 1026/1026 [==============================] - 0s 300us/sample - loss: 59.8146
# Epoch 98/200
# 1026/1026 [==============================] - 0s 287us/sample - loss: 62.2459
# Epoch 99/200
# 1026/1026 [==============================] - 0s 284us/sample - loss: 61.5178
# Epoch 100/200
# 1026/1026 [==============================] - 0s 323us/sample - loss: 63.2516
# Epoch 101/200
# 1026/1026 [==============================] - 0s 306us/sample - loss: 67.2304
# Epoch 102/200
# 1026/1026 [==============================] - 0s 292us/sample - loss: 52.5526
# Epoch 103/200
# 1026/1026 [==============================] - 0s 291us/sample - loss: 65.1422
# Epoch 104/200
# 1026/1026 [==============================] - 0s 280us/sample - loss: 63.1339
# Epoch 105/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 61.6843
# Epoch 106/200
# 1026/1026 [==============================] - 0s 279us/sample - loss: 62.5177
# Epoch 107/200
# 1026/1026 [==============================] - 0s 297us/sample - loss: 68.7940
# Epoch 108/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 78.2908
# Epoch 109/200
# 1026/1026 [==============================] - 0s 292us/sample - loss: 59.8789
# Epoch 110/200
# 1026/1026 [==============================] - 0s 301us/sample - loss: 59.8087
# Epoch 111/200
# 1026/1026 [==============================] - 0s 307us/sample - loss: 67.4273
# Epoch 112/200
# 1026/1026 [==============================] - 0s 287us/sample - loss: 54.2404
# Epoch 113/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 45.8116
# Epoch 114/200
# 1026/1026 [==============================] - 0s 281us/sample - loss: 68.0984
# Epoch 115/200
# 1026/1026 [==============================] - 0s 318us/sample - loss: 55.3004
# Epoch 116/200
# 1026/1026 [==============================] - 0s 313us/sample - loss: 63.6798
# Epoch 117/200
# 1026/1026 [==============================] - 0s 288us/sample - loss: 64.3777
# Epoch 118/200
# 1026/1026 [==============================] - 0s 330us/sample - loss: 54.5443
# Epoch 119/200
# 1026/1026 [==============================] - 0s 340us/sample - loss: 46.6113
# Epoch 120/200
# 1026/1026 [==============================] - 0s 308us/sample - loss: 60.2076
# Epoch 121/200
# 1026/1026 [==============================] - 0s 307us/sample - loss: 44.1222
# Epoch 122/200
# 1026/1026 [==============================] - 0s 305us/sample - loss: 51.0076
# Epoch 123/200
# 1026/1026 [==============================] - 0s 301us/sample - loss: 63.6674
# Epoch 124/200
# 1026/1026 [==============================] - 0s 296us/sample - loss: 53.0463
# Epoch 125/200
# 1026/1026 [==============================] - 0s 296us/sample - loss: 48.8227
# Epoch 126/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 47.3115
# Epoch 127/200
# 1026/1026 [==============================] - 0s 295us/sample - loss: 57.8796
# Epoch 128/200
# 1026/1026 [==============================] - 0s 289us/sample - loss: 53.9041
# Epoch 129/200
# 1026/1026 [==============================] - 0s 289us/sample - loss: 42.4340
# Epoch 130/200
# 1026/1026 [==============================] - 0s 291us/sample - loss: 53.9264
# Epoch 131/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 37.7611
# Epoch 132/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 59.9311
# Epoch 133/200
# 1026/1026 [==============================] - 0s 292us/sample - loss: 61.0424
# Epoch 134/200
# 1026/1026 [==============================] - 0s 294us/sample - loss: 41.9935
# Epoch 135/200
# 1026/1026 [==============================] - 0s 298us/sample - loss: 51.3121
# Epoch 136/200
# 1026/1026 [==============================] - 0s 321us/sample - loss: 41.0853
# Epoch 137/200
# 1026/1026 [==============================] - 0s 326us/sample - loss: 46.4881
# Epoch 138/200
# 1026/1026 [==============================] - 0s 339us/sample - loss: 47.1245
# Epoch 139/200
# 1026/1026 [==============================] - 0s 308us/sample - loss: 50.3488
# Epoch 140/200
# 1026/1026 [==============================] - 0s 307us/sample - loss: 46.7650
# Epoch 141/200
# 1026/1026 [==============================] - 0s 291us/sample - loss: 37.7749
# Epoch 142/200
# 1026/1026 [==============================] - 0s 296us/sample - loss: 41.3253
# Epoch 143/200
# 1026/1026 [==============================] - 0s 287us/sample - loss: 68.9795
# Epoch 144/200
# 1026/1026 [==============================] - 0s 297us/sample - loss: 43.0093
# Epoch 145/200
# 1026/1026 [==============================] - 0s 292us/sample - loss: 40.4642
# Epoch 146/200
# 1026/1026 [==============================] - 0s 297us/sample - loss: 47.1099
# Epoch 147/200
# 1026/1026 [==============================] - 0s 301us/sample - loss: 45.7711
# Epoch 148/200
# 1026/1026 [==============================] - 0s 308us/sample - loss: 54.8796
# Epoch 149/200
# 1026/1026 [==============================] - 0s 327us/sample - loss: 36.2989
# Epoch 150/200
# 1026/1026 [==============================] - 0s 344us/sample - loss: 37.8306
# Epoch 151/200
# 1026/1026 [==============================] - 0s 298us/sample - loss: 41.4502
# Epoch 152/200
# 1026/1026 [==============================] - 0s 289us/sample - loss: 49.2310
# Epoch 153/200
# 1026/1026 [==============================] - 0s 297us/sample - loss: 44.8862
# Epoch 154/200
# 1026/1026 [==============================] - 0s 283us/sample - loss: 31.8828
# Epoch 155/200
# 1026/1026 [==============================] - 0s 296us/sample - loss: 40.3459
# Epoch 156/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 37.7863
# Epoch 157/200
# 1026/1026 [==============================] - 0s 284us/sample - loss: 40.3354
# Epoch 158/200
# 1026/1026 [==============================] - 0s 299us/sample - loss: 42.3428
# Epoch 159/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 40.0161
# Epoch 160/200
# 1026/1026 [==============================] - 0s 298us/sample - loss: 35.1190
# Epoch 161/200
# 1026/1026 [==============================] - 0s 302us/sample - loss: 32.6619
# Epoch 162/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 33.4415
# Epoch 163/200
# 1026/1026 [==============================] - 0s 323us/sample - loss: 34.3643
# Epoch 164/200
# 1026/1026 [==============================] - 0s 308us/sample - loss: 37.1896 - los
# Epoch 165/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 37.2690
# Epoch 166/200
# 1026/1026 [==============================] - 0s 313us/sample - loss: 38.7474
# Epoch 167/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 39.1634
# Epoch 168/200
# 1026/1026 [==============================] - 0s 285us/sample - loss: 26.8528
# Epoch 169/200
# 1026/1026 [==============================] - 0s 301us/sample - loss: 39.4179
# Epoch 170/200
# 1026/1026 [==============================] - 0s 284us/sample - loss: 41.1527
# Epoch 171/200
# 1026/1026 [==============================] - 0s 290us/sample - loss: 45.2160
# Epoch 172/200
# 1026/1026 [==============================] - 0s 298us/sample - loss: 31.5336
# Epoch 173/200
# 1026/1026 [==============================] - 0s 346us/sample - loss: 34.1841
# Epoch 174/200
# 1026/1026 [==============================] - 0s 310us/sample - loss: 36.5376
# Epoch 175/200
# 1026/1026 [==============================] - 0s 296us/sample - loss: 45.6500
# Epoch 176/200
# 1026/1026 [==============================] - 0s 297us/sample - loss: 43.8888
# Epoch 177/200
# 1026/1026 [==============================] - 0s 283us/sample - loss: 33.0476
# Epoch 178/200
# 1026/1026 [==============================] - 0s 333us/sample - loss: 35.1793
# Epoch 179/200
# 1026/1026 [==============================] - 0s 312us/sample - loss: 26.1042
# Epoch 180/200
# 1026/1026 [==============================] - 0s 293us/sample - loss: 38.7272
# Epoch 181/200
# 1026/1026 [==============================] - 0s 284us/sample - loss: 31.8642
# Epoch 182/200
# 1026/1026 [==============================] - 0s 280us/sample - loss: 32.9978
# Epoch 183/200
# 1026/1026 [==============================] - 0s 267us/sample - loss: 29.7986
# Epoch 184/200
# 1026/1026 [==============================] - 0s 263us/sample - loss: 30.3222
# Epoch 185/200
# 1026/1026 [==============================] - 0s 264us/sample - loss: 31.7800
# Epoch 186/200
# 1026/1026 [==============================] - 0s 270us/sample - loss: 23.5525
# Epoch 187/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 33.8962 - loss: 2
# Epoch 188/200
# 1026/1026 [==============================] - 0s 267us/sample - loss: 41.1475
# Epoch 189/200
# 1026/1026 [==============================] - 0s 278us/sample - loss: 41.3013
# Epoch 190/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 46.7929
# Epoch 191/200
# 1026/1026 [==============================] - 0s 312us/sample - loss: 47.2456
# Epoch 192/200
# 1026/1026 [==============================] - 0s 272us/sample - loss: 28.2792
# Epoch 193/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 34.2813
# Epoch 194/200
# 1026/1026 [==============================] - 0s 270us/sample - loss: 27.8450
# Epoch 195/200
# 1026/1026 [==============================] - 0s 269us/sample - loss: 30.9768
# Epoch 196/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 26.8568
# Epoch 197/200
# 1026/1026 [==============================] - 0s 274us/sample - loss: 27.4312
# Epoch 198/200
# 1026/1026 [==============================] - 0s 268us/sample - loss: 34.8781
# Epoch 199/200
# 1026/1026 [==============================] - 0s 273us/sample - loss: 34.5311
# Epoch 200/200
# 1026/1026 [==============================] - 0s 277us/sample - loss: 32.9384

# %%
model3 = create_model(input_dim=8)
history = model3.fit(
    X3_train_scaled,
    y3_train,
    epochs=200,
    batch_size = 6,
#     shuffle=True,
    verbose=1
)
# Out:
# Train on 882 samples
# Epoch 1/200
# 882/882 [==============================] - 1s 911us/sample - loss: 15350.7704
# Epoch 2/200
# 882/882 [==============================] - 0s 303us/sample - loss: 687.3086
# Epoch 3/200
# 882/882 [==============================] - 0s 298us/sample - loss: 374.1517
# Epoch 4/200
# 882/882 [==============================] - 0s 294us/sample - loss: 293.2482
# Epoch 5/200
# 882/882 [==============================] - 0s 302us/sample - loss: 208.0489
# Epoch 6/200
# 882/882 [==============================] - 0s 286us/sample - loss: 207.0385
# Epoch 7/200
# 882/882 [==============================] - 0s 282us/sample - loss: 173.3001
# Epoch 8/200
# 882/882 [==============================] - 0s 295us/sample - loss: 167.6284
# Epoch 9/200
# 882/882 [==============================] - 0s 296us/sample - loss: 145.7201
# Epoch 10/200
# 882/882 [==============================] - 0s 282us/sample - loss: 162.2188
# Epoch 11/200
# 882/882 [==============================] - 0s 297us/sample - loss: 138.0933
# Epoch 12/200
# 882/882 [==============================] - 0s 286us/sample - loss: 168.2908
# Epoch 13/200
# 882/882 [==============================] - 0s 291us/sample - loss: 171.7135
# Epoch 14/200
# 882/882 [==============================] - 0s 296us/sample - loss: 154.5683
# Epoch 15/200
# 882/882 [==============================] - 0s 295us/sample - loss: 118.5429
# Epoch 16/200
# 882/882 [==============================] - 0s 282us/sample - loss: 156.5078
# Epoch 17/200
# 882/882 [==============================] - 0s 301us/sample - loss: 122.0847
# Epoch 18/200
# 882/882 [==============================] - 0s 299us/sample - loss: 150.3410
# Epoch 19/200
# 882/882 [==============================] - 0s 290us/sample - loss: 102.1399
# Epoch 20/200
# 882/882 [==============================] - 0s 297us/sample - loss: 106.0903
# Epoch 21/200
# 882/882 [==============================] - 0s 292us/sample - loss: 130.3010
# Epoch 22/200
# 882/882 [==============================] - 0s 286us/sample - loss: 110.5685
# Epoch 23/200
# 882/882 [==============================] - 0s 289us/sample - loss: 124.3468
# Epoch 24/200
# 882/882 [==============================] - 0s 297us/sample - loss: 102.8532
# Epoch 25/200
# 882/882 [==============================] - 0s 284us/sample - loss: 121.4976
# Epoch 26/200
# 882/882 [==============================] - 0s 289us/sample - loss: 123.9438
# Epoch 27/200
# 882/882 [==============================] - 0s 284us/sample - loss: 115.7000
# Epoch 28/200
# 882/882 [==============================] - 0s 287us/sample - loss: 135.4251
# Epoch 29/200
# 882/882 [==============================] - 0s 297us/sample - loss: 106.7181
# Epoch 30/200
# 882/882 [==============================] - 0s 305us/sample - loss: 126.5585
# Epoch 31/200
# 882/882 [==============================] - 0s 291us/sample - loss: 106.0748
# Epoch 32/200
# 882/882 [==============================] - 0s 297us/sample - loss: 132.6070
# Epoch 33/200
# 882/882 [==============================] - 0s 282us/sample - loss: 100.6702
# Epoch 34/200
# 882/882 [==============================] - 0s 304us/sample - loss: 91.0150
# Epoch 35/200
# 882/882 [==============================] - 0s 289us/sample - loss: 98.1492
# Epoch 36/200
# 882/882 [==============================] - 0s 290us/sample - loss: 102.4436
# Epoch 37/200
# 882/882 [==============================] - 0s 286us/sample - loss: 144.5538
# Epoch 38/200
# 882/882 [==============================] - 0s 286us/sample - loss: 118.4855
# Epoch 39/200
# 882/882 [==============================] - 0s 289us/sample - loss: 115.0989
# Epoch 40/200
# 882/882 [==============================] - 0s 302us/sample - loss: 87.8520
# Epoch 41/200
# 882/882 [==============================] - 0s 292us/sample - loss: 95.4421
# Epoch 42/200
# 882/882 [==============================] - 0s 308us/sample - loss: 91.1012
# Epoch 43/200
# 882/882 [==============================] - 0s 293us/sample - loss: 118.5166
# Epoch 44/200
# 882/882 [==============================] - 0s 300us/sample - loss: 119.1837
# Epoch 45/200
# 882/882 [==============================] - 0s 292us/sample - loss: 103.5023
# Epoch 46/200
# 882/882 [==============================] - 0s 292us/sample - loss: 128.0966
# Epoch 47/200
# 882/882 [==============================] - 0s 305us/sample - loss: 114.7097
# Epoch 48/200
# 882/882 [==============================] - 0s 289us/sample - loss: 87.2781
# Epoch 49/200
# 882/882 [==============================] - 0s 300us/sample - loss: 116.6602
# Epoch 50/200
# 882/882 [==============================] - 0s 286us/sample - loss: 115.2111
# Epoch 51/200
# 882/882 [==============================] - 0s 309us/sample - loss: 95.2400
# Epoch 52/200
# 882/882 [==============================] - 0s 287us/sample - loss: 91.6489
# Epoch 53/200
# 882/882 [==============================] - 0s 303us/sample - loss: 100.3677
# Epoch 54/200
# 882/882 [==============================] - 0s 331us/sample - loss: 101.2592
# Epoch 55/200
# 882/882 [==============================] - 0s 294us/sample - loss: 113.9907
# Epoch 56/200
# 882/882 [==============================] - 0s 274us/sample - loss: 84.9424
# Epoch 57/200
# 882/882 [==============================] - 0s 302us/sample - loss: 84.4328
# Epoch 58/200
# 882/882 [==============================] - 0s 277us/sample - loss: 113.0486
# Epoch 59/200
# 882/882 [==============================] - 0s 279us/sample - loss: 112.7715
# Epoch 60/200
# 882/882 [==============================] - 0s 283us/sample - loss: 104.0121
# Epoch 61/200
# 882/882 [==============================] - 0s 279us/sample - loss: 84.0457
# Epoch 62/200
# 882/882 [==============================] - 0s 283us/sample - loss: 87.7203
# Epoch 63/200
# 882/882 [==============================] - 0s 295us/sample - loss: 96.3828
# Epoch 64/200
# 882/882 [==============================] - 0s 289us/sample - loss: 80.0516
# Epoch 65/200
# 882/882 [==============================] - 0s 288us/sample - loss: 75.0427
# Epoch 66/200
# 882/882 [==============================] - 0s 292us/sample - loss: 83.8159
# Epoch 67/200
# 882/882 [==============================] - 0s 304us/sample - loss: 87.7899
# Epoch 68/200
# 882/882 [==============================] - 0s 304us/sample - loss: 76.6596
# Epoch 69/200
# 882/882 [==============================] - 0s 304us/sample - loss: 89.0360
# Epoch 70/200
# 882/882 [==============================] - 0s 312us/sample - loss: 81.0477
# Epoch 71/200
# 882/882 [==============================] - 0s 321us/sample - loss: 88.2002
# Epoch 72/200
# 882/882 [==============================] - 0s 329us/sample - loss: 78.6453
# Epoch 73/200
# 882/882 [==============================] - 0s 314us/sample - loss: 69.5425
# Epoch 74/200
# 882/882 [==============================] - 0s 294us/sample - loss: 70.6848
# Epoch 75/200
# 882/882 [==============================] - 0s 336us/sample - loss: 85.7728
# Epoch 76/200
# 882/882 [==============================] - 0s 352us/sample - loss: 72.5715
# Epoch 77/200
# 882/882 [==============================] - 0s 312us/sample - loss: 88.6873
# Epoch 78/200
# 882/882 [==============================] - 0s 327us/sample - loss: 76.9412
# Epoch 79/200
# 882/882 [==============================] - 0s 336us/sample - loss: 99.1703
# Epoch 80/200
# 882/882 [==============================] - 0s 349us/sample - loss: 76.9822
# Epoch 81/200
# 882/882 [==============================] - 0s 336us/sample - loss: 80.5765
# Epoch 82/200
# 882/882 [==============================] - 0s 389us/sample - loss: 66.6812
# Epoch 83/200
# 882/882 [==============================] - 0s 360us/sample - loss: 82.4427
# Epoch 84/200
# 882/882 [==============================] - 0s 340us/sample - loss: 72.2886
# Epoch 85/200
# 882/882 [==============================] - 0s 373us/sample - loss: 78.4614
# Epoch 86/200
# 882/882 [==============================] - 0s 344us/sample - loss: 67.2040
# Epoch 87/200
# 882/882 [==============================] - 0s 328us/sample - loss: 74.0075
# Epoch 88/200
# 882/882 [==============================] - 0s 335us/sample - loss: 77.7519
# Epoch 89/200
# 882/882 [==============================] - 0s 340us/sample - loss: 79.6582
# Epoch 90/200
# 882/882 [==============================] - 0s 329us/sample - loss: 71.6110
# Epoch 91/200
# 882/882 [==============================] - 0s 344us/sample - loss: 62.6374
# Epoch 92/200
# 882/882 [==============================] - 0s 327us/sample - loss: 80.9463
# Epoch 93/200
# 882/882 [==============================] - 0s 313us/sample - loss: 109.3296
# Epoch 94/200
# 882/882 [==============================] - 0s 297us/sample - loss: 81.8227
# Epoch 95/200
# 882/882 [==============================] - 0s 289us/sample - loss: 128.7672
# Epoch 96/200
# 882/882 [==============================] - 0s 280us/sample - loss: 59.4987
# Epoch 97/200
# 882/882 [==============================] - 0s 285us/sample - loss: 103.7523
# Epoch 98/200
# 882/882 [==============================] - 0s 301us/sample - loss: 76.1710
# Epoch 99/200
# 882/882 [==============================] - 0s 279us/sample - loss: 58.3883
# Epoch 100/200
# 882/882 [==============================] - 0s 287us/sample - loss: 58.9605
# Epoch 101/200
# 882/882 [==============================] - 0s 289us/sample - loss: 87.7081
# Epoch 102/200
# 882/882 [==============================] - 0s 289us/sample - loss: 61.2697
# Epoch 103/200
# 882/882 [==============================] - 0s 282us/sample - loss: 71.7768
# Epoch 104/200
# 882/882 [==============================] - 0s 275us/sample - loss: 89.0548
# Epoch 105/200
# 882/882 [==============================] - 0s 286us/sample - loss: 62.6770
# Epoch 106/200
# 882/882 [==============================] - 0s 286us/sample - loss: 66.0588
# Epoch 107/200
# 882/882 [==============================] - 0s 278us/sample - loss: 70.3100
# Epoch 108/200
# 882/882 [==============================] - 0s 280us/sample - loss: 66.2594
# Epoch 109/200
# 882/882 [==============================] - 0s 293us/sample - loss: 60.5341
# Epoch 110/200
# 882/882 [==============================] - 0s 287us/sample - loss: 66.3662
# Epoch 111/200
# 882/882 [==============================] - 0s 285us/sample - loss: 59.4808
# Epoch 112/200
# 882/882 [==============================] - 0s 277us/sample - loss: 58.6376
# Epoch 113/200
# 882/882 [==============================] - 0s 293us/sample - loss: 74.1184
# Epoch 114/200
# 882/882 [==============================] - 0s 299us/sample - loss: 57.7544
# Epoch 115/200
# 882/882 [==============================] - 0s 279us/sample - loss: 53.4389
# Epoch 116/200
# 882/882 [==============================] - 0s 282us/sample - loss: 49.6041
# Epoch 117/200
# 882/882 [==============================] - 0s 287us/sample - loss: 71.6037
# Epoch 118/200
# 882/882 [==============================] - 0s 288us/sample - loss: 49.1623
# Epoch 119/200
# 882/882 [==============================] - 0s 279us/sample - loss: 53.0758
# Epoch 120/200
# 882/882 [==============================] - 0s 317us/sample - loss: 58.2048
# Epoch 121/200
# 882/882 [==============================] - 0s 306us/sample - loss: 58.7856
# Epoch 122/200
# 882/882 [==============================] - 0s 299us/sample - loss: 60.5771
# Epoch 123/200
# 882/882 [==============================] - 0s 288us/sample - loss: 72.1162
# Epoch 124/200
# 882/882 [==============================] - 0s 282us/sample - loss: 76.5802
# Epoch 125/200
# 882/882 [==============================] - 0s 331us/sample - loss: 54.5983
# Epoch 126/200
# 882/882 [==============================] - 0s 309us/sample - loss: 53.2812
# Epoch 127/200
# 882/882 [==============================] - 0s 288us/sample - loss: 49.2970
# Epoch 128/200
# 882/882 [==============================] - 0s 282us/sample - loss: 68.7114
# Epoch 129/200
# 882/882 [==============================] - 0s 297us/sample - loss: 50.6039
# Epoch 130/200
# 882/882 [==============================] - 0s 300us/sample - loss: 58.1609
# Epoch 131/200
# 882/882 [==============================] - 0s 296us/sample - loss: 54.7406
# Epoch 132/200
# 882/882 [==============================] - 0s 293us/sample - loss: 71.9437
# Epoch 133/200
# 882/882 [==============================] - 0s 296us/sample - loss: 49.4046
# Epoch 134/200
# 882/882 [==============================] - 0s 300us/sample - loss: 52.4062
# Epoch 135/200
# 882/882 [==============================] - 0s 299us/sample - loss: 44.8385
# Epoch 136/200
# 882/882 [==============================] - 0s 307us/sample - loss: 66.3820
# Epoch 137/200
# 882/882 [==============================] - 0s 298us/sample - loss: 43.8206
# Epoch 138/200
# 882/882 [==============================] - 0s 292us/sample - loss: 61.2247
# Epoch 139/200
# 882/882 [==============================] - 0s 296us/sample - loss: 49.3909
# Epoch 140/200
# 882/882 [==============================] - 0s 288us/sample - loss: 54.8600
# Epoch 141/200
# 882/882 [==============================] - 0s 286us/sample - loss: 52.4899
# Epoch 142/200
# 882/882 [==============================] - 0s 302us/sample - loss: 43.2488
# Epoch 143/200
# 882/882 [==============================] - 0s 294us/sample - loss: 42.3225
# Epoch 144/200
# 882/882 [==============================] - 0s 288us/sample - loss: 54.3094
# Epoch 145/200
# 882/882 [==============================] - 0s 296us/sample - loss: 54.9264
# Epoch 146/200
# 882/882 [==============================] - 0s 283us/sample - loss: 51.4591
# Epoch 147/200
# 882/882 [==============================] - 0s 310us/sample - loss: 40.7689
# Epoch 148/200
# 882/882 [==============================] - 0s 305us/sample - loss: 62.3107
# Epoch 149/200
# 882/882 [==============================] - 0s 301us/sample - loss: 46.5265
# Epoch 150/200
# 882/882 [==============================] - 0s 308us/sample - loss: 52.7565
# Epoch 151/200
# 882/882 [==============================] - 0s 395us/sample - loss: 73.6389
# Epoch 152/200
# 882/882 [==============================] - 0s 328us/sample - loss: 53.0938
# Epoch 153/200
# 882/882 [==============================] - 0s 309us/sample - loss: 41.7557
# Epoch 154/200
# 882/882 [==============================] - 0s 302us/sample - loss: 49.4993
# Epoch 155/200
# 882/882 [==============================] - 0s 301us/sample - loss: 53.4586
# Epoch 156/200
# 882/882 [==============================] - 0s 291us/sample - loss: 45.0934
# Epoch 157/200
# 882/882 [==============================] - 0s 277us/sample - loss: 47.0723
# Epoch 158/200
# 882/882 [==============================] - 0s 282us/sample - loss: 50.5000
# Epoch 159/200
# 882/882 [==============================] - 0s 287us/sample - loss: 37.1761
# Epoch 160/200
# 882/882 [==============================] - 0s 284us/sample - loss: 60.3345
# Epoch 161/200
# 882/882 [==============================] - 0s 282us/sample - loss: 44.9514
# Epoch 162/200
# 882/882 [==============================] - 0s 282us/sample - loss: 41.4781
# Epoch 163/200
# 882/882 [==============================] - 0s 287us/sample - loss: 48.9489
# Epoch 164/200
# 882/882 [==============================] - 0s 283us/sample - loss: 37.0326
# Epoch 165/200
# 882/882 [==============================] - 0s 292us/sample - loss: 39.2431
# Epoch 166/200
# 882/882 [==============================] - 0s 310us/sample - loss: 36.3447
# Epoch 167/200
# 882/882 [==============================] - 0s 310us/sample - loss: 50.5453
# Epoch 168/200
# 882/882 [==============================] - 0s 306us/sample - loss: 37.2760
# Epoch 169/200
# 882/882 [==============================] - 0s 303us/sample - loss: 36.2431
# Epoch 170/200
# 882/882 [==============================] - 0s 302us/sample - loss: 41.5743
# Epoch 171/200
# 882/882 [==============================] - 0s 303us/sample - loss: 42.4428
# Epoch 172/200
# 882/882 [==============================] - 0s 296us/sample - loss: 36.7947
# Epoch 173/200
# 882/882 [==============================] - 0s 283us/sample - loss: 48.0064
# Epoch 174/200
# 882/882 [==============================] - 0s 287us/sample - loss: 61.2518
# Epoch 175/200
# 882/882 [==============================] - 0s 288us/sample - loss: 36.8001
# Epoch 176/200
# 882/882 [==============================] - 0s 283us/sample - loss: 39.1605
# Epoch 177/200
# 882/882 [==============================] - 0s 283us/sample - loss: 48.9734
# Epoch 178/200
# 882/882 [==============================] - 0s 298us/sample - loss: 50.4434
# Epoch 179/200
# 882/882 [==============================] - 0s 305us/sample - loss: 39.1805
# Epoch 180/200
# 882/882 [==============================] - 0s 302us/sample - loss: 32.2071
# Epoch 181/200
# 882/882 [==============================] - 0s 295us/sample - loss: 31.3537
# Epoch 182/200
# 882/882 [==============================] - 0s 308us/sample - loss: 30.3945
# Epoch 183/200
# 882/882 [==============================] - 0s 290us/sample - loss: 33.7808
# Epoch 184/200
# 882/882 [==============================] - 0s 292us/sample - loss: 35.9000
# Epoch 185/200
# 882/882 [==============================] - 0s 268us/sample - loss: 40.2096
# Epoch 186/200
# 882/882 [==============================] - 0s 276us/sample - loss: 42.5061
# Epoch 187/200
# 882/882 [==============================] - 0s 262us/sample - loss: 38.7455
# Epoch 188/200
# 882/882 [==============================] - 0s 267us/sample - loss: 30.3605
# Epoch 189/200
# 882/882 [==============================] - 0s 265us/sample - loss: 39.0894
# Epoch 190/200
# 882/882 [==============================] - 0s 273us/sample - loss: 33.8791
# Epoch 191/200
# 882/882 [==============================] - 0s 269us/sample - loss: 27.8452
# Epoch 192/200
# 882/882 [==============================] - 0s 265us/sample - loss: 39.9443
# Epoch 193/200
# 882/882 [==============================] - 0s 265us/sample - loss: 41.2752
# Epoch 194/200
# 882/882 [==============================] - 0s 268us/sample - loss: 36.5801
# Epoch 195/200
# 882/882 [==============================] - 0s 280us/sample - loss: 39.4320
# Epoch 196/200
# 882/882 [==============================] - 0s 266us/sample - loss: 28.2090
# Epoch 197/200
# 882/882 [==============================] - 0s 267us/sample - loss: 31.3592
# Epoch 198/200
# 882/882 [==============================] - 0s 270us/sample - loss: 54.1548
# Epoch 199/200
# 882/882 [==============================] - 0s 277us/sample - loss: 56.2733
# Epoch 200/200
# 882/882 [==============================] - 0s 257us/sample - loss: 46.2896

# %%
# plot loss during training
plt.title('Loss / Mean Squared Error')
plt.plot(history.history['loss'], label='train')
plt.legend()
plt.show()

# %%
y_pred = model1.predict(X_test_scaled)
r2_score(y_test, y_pred)
# Out:
# 0.8391167256279477

# %%
# withiout covid as a parameter
y2_pred = model2.predict(X2_test_scaled)
r2_score(y2_test, y2_pred)
# Out:
# 0.8548715999026676

# %%
y3_pred = model3.predict(X3_test_scaled)
r2_score(y3_test, y3_pred)
# Out:
# 0.7511549065337384

# %%
y_train_pred = model1.predict(X_train_scaled)
r2_score(y_train, y_train_pred)
# Out:
# 0.9576458580902227

# %%
plt.scatter(y_train,model1.predict(X_train_scaled))
plt.grid()
plt.xlabel('Actual Electricity Consumption')
plt.ylabel('Predicted Electricity Consumption')
plt.title('Scatter plot between actual consumption and predicted consumption')
plt.show()
print('Mean Squared Error :',mean_squared_error(y_test, model1.predict(X_test_scaled)))
print('Mean Absolute Error :',mean_absolute_error(y_test, model1.predict(X_test_scaled)))
# Out:
# Mean Squared Error : 117.53443423634957
# Mean Absolute Error : 8.262887831262532

# %%
plt.scatter(y2_train,model2.predict(X2_train_scaled))
plt.grid()
plt.xlabel('Actual Electricity Consumption')
plt.ylabel('Predicted Electricity Consumption')
plt.title('Scatter plot between actual consumption and predicted consumption')
plt.show()
print('Mean Squared Error :',mean_squared_error(y2_test, model2.predict(X2_test_scaled)))
print('Mean Absolute Error :',mean_absolute_error(y2_test, model2.predict(X2_test_scaled)))
# Out:
# Mean Squared Error : 106.02459742098392
# Mean Absolute Error : 7.868942820457705

# %%
plt.scatter(y3_train,model3.predict(X3_train_scaled))
plt.grid()
plt.xlabel('Actual Electricity Consumption')
plt.ylabel('Predicted Electricity Consumption')
plt.title('Scatter plot between actual consumption and predicted consumption')
plt.show()
print('Mean Squared Error :',mean_squared_error(y3_test, model3.predict(X3_test_scaled)))
print('Mean Absolute Error :',mean_absolute_error(y3_test, model3.predict(X3_test_scaled)))
# Out:
# Mean Squared Error : 180.6020137996905
# Mean Absolute Error : 10.608319468221856

# %%
model_loss = model1.evaluate(X_train_scaled, y_train, verbose=1)
# print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1026/1026 [==============================] - 0s 243us/sample - loss: 31.6514

# %%
diff = y_pred - y_test
percentDiff = (diff / y_test) * 100
absPercentDiff = np.abs(percentDiff)
# compute the mean and standard deviation of the absolute percentage
# difference
mean = np.mean(absPercentDiff)
std = np.std(absPercentDiff)
print("[INFO] mean of the absolute percentage difference: {:.2f}%, std of the absolute percentage difference: {:.2f}%".format(mean, std))
# Out:
# [INFO] mean of the absolute percentage difference: 3.54%, std of the absolute percentage difference: 3.01%

# %%
diff = y2_pred - y2_test
percentDiff = (diff / y2_test) * 100
absPercentDiff = np.abs(percentDiff)
# compute the mean and standard deviation of the absolute percentage
# difference
mean2 = np.mean(absPercentDiff)
std2 = np.std(absPercentDiff)
print("[INFO] mean of the absolute percentage difference: {:.2f}%, std of the absolute percentage difference: {:.2f}%".format(mean2, std2))
# Out:
# [INFO] mean of the absolute percentage difference: 3.39%, std of the absolute percentage difference: 2.95%

# %%
diff = y3_pred - y3_test
percentDiff = (diff / y3_test) * 100
absPercentDiff = np.abs(percentDiff)
# compute the mean and standard deviation of the absolute percentage
# difference
mean3 = np.mean(absPercentDiff)
std3 = np.std(absPercentDiff)
print("[INFO] mean of the absolute percentage difference: {:.2f}%, std of the absolute percentage difference: {:.2f}%".format(mean3, std3))
# Out:
# [INFO] mean of the absolute percentage difference: 4.60%, std of the absolute percentage difference: 3.64%

# %%
y_test_df= pd.DataFrame(y2_test,columns= {'demand'})

# %%
X2_test = X2_test.reset_index()
df = pd.merge(X2_test, y_test_df, left_index=True, right_index=True)

# %%
y_pred_df= pd.DataFrame(y2_pred,columns= {'demand_prediction'})

# %%
df_demand = pd.merge(df, y_pred_df, left_index=True, right_index=True)

# %%
df_demand['date'] = pd.to_datetime(df[['year', 'month', 'day']])
df_demand['Prediction_Variation'] = df_demand['demand_prediction'] - df_demand['demand']

# %%
df_demand.plot.line(figsize=(16, 10),x="date", y=["demand", "demand_prediction"],rot=0,style='.-', xlim=('2019-10-01','2020-09-30'))
plt.xlabel("Date", labelpad=30)
plt.ylabel("Daily Electricity Demand GWh", labelpad=15)
plt.title("Victoria Electricity Actual Demand Vs Prediction on Test Data", fontsize=16);
plt.grid()
plt.show()

# %%
df_demand.plot.bar(figsize=(16, 10),x="date", y=["Prediction_Variation"])
plt.xlabel("Date")
plt.xticks(rotation='horizontal')
plt.ylabel("Daily Electricity Demand GWh", labelpad=15)
plt.title("Victoria Electricity Demand Prediction Variation from Actual", fontsize=22);
plt.tight_layout()
plt.show()
